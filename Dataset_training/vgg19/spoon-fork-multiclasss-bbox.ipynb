# %%
import pandas as pd
import cv2
import numpy as np
import os 
import tensorflow as tf

df = pd.read_csv('/kaggle/input/sssasdasd/train/_annotations.csv')
image_dir = '/kaggle/input/sssasdasd/train'
images = []
labels = []
bboxes = []

for _, row in df.iterrows():
   
    try:
        img_path = os.path.join(image_dir, row['filename'])
        img = cv2.imread(img_path)

       
        img = cv2.resize(img, (224, 224)) / 255.0
        images.append(img)
        label = 0 if row['class'] == 'fork' else 1
        labels.append(label)


    except Exception as e:
        print(str(e))
 


    # Normalize bounding boxes
    bbox = [
        row['xmin'] / row['width'],
        row['ymin'] / row['height'],
        row['xmax'] / row['width'],
        row['ymax'] / row['height']
    ]
    bboxes.append(bbox)

X = np.array(images)
y_class = np.array(labels)
y_bbox = np.array(bboxes)

# %%
def iou_metric(y_true, y_pred):
    x_min = tf.maximum(y_true[:, 0], y_pred[:, 0])
    y_min = tf.maximum(y_true[:, 1], y_pred[:, 1])
    x_max = tf.minimum(y_true[:, 2], y_pred[:, 2])
    y_max = tf.minimum(y_true[:, 3], y_pred[:, 3])

    intersection = tf.maximum(x_max - x_min, 0) * tf.maximum(y_max - y_min, 0)
    true_area = (y_true[:, 2] - y_true[:, 0]) * (y_true[:, 3] - y_true[:, 1])
    pred_area = (y_pred[:, 2] - y_pred[:, 0]) * (y_pred[:, 3] - y_pred[:, 1])
    union = true_area + pred_area - intersection

    iou = intersection / tf.maximum(union, tf.keras.backend.epsilon())
    return tf.reduce_mean(iou)

# %%
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Dense, Dropout, Flatten, GlobalAveragePooling2D, BatchNormalization, Input
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.applications import VGG19

# Giriş boyutları
img_width, img_height = 224, 224

# Pre-trained VGG19 modeli
base_model = VGG19(weights='imagenet', include_top=False, input_shape=(img_height, img_width, 3))

# Pre-trained katmanları dondur
for layer in base_model.layers:
    layer.trainable = False

# Modelin üst kısmını oluştur
x = base_model.output
x = GlobalAveragePooling2D()(x)


# Sınıf tahmini (Sigmoid aktivasyonu ile ikili sınıflandırma)
class_output = Dense(1, activation='sigmoid', name='class_output')(x)

bbox_output = Dense(4, activation='linear', name='bbox_output')(x)

# Modelin giriş ve çıkışları
model = Model(inputs=base_model.input, outputs=[class_output, bbox_output])

# Modelin derlenmesi
model.compile(
    loss={
        'class_output': 'binary_crossentropy',
        'bbox_output': 'mean_squared_error'
    },
    optimizer=Adam(learning_rate=0.001),
    metrics={
        'class_output': ['accuracy'],
        'bbox_output':  [iou_metric]
    }
)

# Model özeti
model.summary()

# Eğitim
history = model.fit(
    X,  # Giriş görüntüleri
    {
        'class_output': y_class,  # Sınıf etiketleri
        'bbox_output': y_bbox  # Bounding box koordinatları
    },
    validation_split=0.2,
    steps_per_epoch= 50,
    epochs=200,
    batch_size=64
)
# Out:
# Model: "functional_2"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)              ┃ Output Shape           ┃        Param # ┃ Connected to           ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━┩
# │ input_layer_2             │ (None, 224, 224, 3)    │              0 │ -                      │
# │ (InputLayer)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block1_conv1 (Conv2D)     │ (None, 224, 224, 64)   │          1,792 │ input_layer_2[0][0]    │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block1_conv2 (Conv2D)     │ (None, 224, 224, 64)   │         36,928 │ block1_conv1[0][0]     │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block1_pool               │ (None, 112, 112, 64)   │              0 │ block1_conv2[0][0]     │
# │ (MaxPooling2D)            │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block2_conv1 (Conv2D)     │ (None, 112, 112, 128)  │         73,856 │ block1_pool[0][0]      │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block2_conv2 (Conv2D)     │ (None, 112, 112, 128)  │        147,584 │ block2_conv1[0][0]     │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block2_pool               │ (None, 56, 56, 128)    │              0 │ block2_conv2[0][0]     │
# │ (MaxPooling2D)            │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block3_conv1 (Conv2D)     │ (None, 56, 56, 256)    │        295,168 │ block2_pool[0][0]      │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block3_conv2 (Conv2D)     │ (None, 56, 56, 256)    │        590,080 │ block3_conv1[0][0]     │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block3_conv3 (Conv2D)     │ (None, 56, 56, 256)    │        590,080 │ block3_conv2[0][0]     │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block3_conv4 (Conv2D)     │ (None, 56, 56, 256)    │        590,080 │ block3_conv3[0][0]     │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block3_pool               │ (None, 28, 28, 256)    │              0 │ block3_conv4[0][0]     │
# │ (MaxPooling2D)            │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block4_conv1 (Conv2D)     │ (None, 28, 28, 512)    │      1,180,160 │ block3_pool[0][0]      │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block4_conv2 (Conv2D)     │ (None, 28, 28, 512)    │      2,359,808 │ block4_conv1[0][0]     │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block4_conv3 (Conv2D)     │ (None, 28, 28, 512)    │      2,359,808 │ block4_conv2[0][0]     │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block4_conv4 (Conv2D)     │ (None, 28, 28, 512)    │      2,359,808 │ block4_conv3[0][0]     │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block4_pool               │ (None, 14, 14, 512)    │              0 │ block4_conv4[0][0]     │
# │ (MaxPooling2D)            │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block5_conv1 (Conv2D)     │ (None, 14, 14, 512)    │      2,359,808 │ block4_pool[0][0]      │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block5_conv2 (Conv2D)     │ (None, 14, 14, 512)    │      2,359,808 │ block5_conv1[0][0]     │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block5_conv3 (Conv2D)     │ (None, 14, 14, 512)    │      2,359,808 │ block5_conv2[0][0]     │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block5_conv4 (Conv2D)     │ (None, 14, 14, 512)    │      2,359,808 │ block5_conv3[0][0]     │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block5_pool               │ (None, 7, 7, 512)      │              0 │ block5_conv4[0][0]     │
# │ (MaxPooling2D)            │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ global_average_pooling2d  │ (None, 512)            │              0 │ block5_pool[0][0]      │
# │ (GlobalAveragePooling2D)  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ class_output (Dense)      │ (None, 1)              │            513 │ global_average_poolin… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ bbox_output (Dense)       │ (None, 4)              │          2,052 │ global_average_poolin… │
# └───────────────────────────┴────────────────────────┴────────────────┴────────────────────────┘
#  Total params: 20,026,949 (76.40 MB)
#  Trainable params: 2,565 (10.02 KB)
#  Non-trainable params: 20,024,384 (76.39 MB)
# Epoch 1/200
#  7/50 ━━━━━━━━━━━━━━━━━━━━ 15s 350ms/step - bbox_output_iou_metric: 0.0000e+00 - class_output_accuracy: 0.5755 - loss: 1.3043
# /usr/lib/python3.10/contextlib.py:153: UserWarning: Your input ran out of data; interrupting training. Make sure that your dataset or generator can generate at least `steps_per_epoch * epochs` batches. You may need to use the `.repeat()` function when building your dataset.
#   self.gen.throw(typ, value, traceback)
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 7s 83ms/step - bbox_output_iou_metric: 0.0000e+00 - class_output_accuracy: 0.5764 - loss: 1.2081 - val_bbox_output_iou_metric: 0.0000e+00 - val_class_output_accuracy: 0.5204 - val_loss: 0.8923
# Epoch 2/200
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - bbox_output_iou_metric: 0.0319 - class_output_accuracy: 0.5893 - loss: 0.8158 - val_bbox_output_iou_metric: 0.2131 - val_class_output_accuracy: 0.5816 - val_loss: 0.7461
# Epoch 3/200
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - bbox_output_iou_metric: 0.2537 - class_output_accuracy: 0.6247 - loss: 0.7331 - val_bbox_output_iou_metric: 0.3353 - val_class_output_accuracy: 0.5204 - val_loss: 0.7406
# Epoch 4/200
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - bbox_output_iou_metric: 0.2923 - class_output_accuracy: 0.6440 - loss: 0.7159 - val_bbox_output_iou_metric: 0.3266 - val_class_output_accuracy: 0.5204 - val_loss: 0.7423
# Epoch 5/200
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - bbox_output_iou_metric: 0.2974 - class_output_accuracy: 0.6342 - loss: 0.6923 - val_bbox_output_iou_metric: 0.3286 - val_class_output_accuracy: 0.5204 - val_loss: 0.7202
# Epoch 6/200
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - bbox_output_iou_metric: 0.2925 - class_output_accuracy: 0.6467 - loss: 0.6674 - val_bbox_output_iou_metric: 0.3243 - val_class_output_accuracy: 0.5510 - val_loss: 0.7021
# Epoch 7/200
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - bbox_output_iou_metric: 0.2715 - class_output_accuracy: 0.6481 - loss: 0.6530 - val_bbox_output_iou_metric: 0.3212 - val_class_output_accuracy: 0.6633 - val_loss: 0.6804
# Epoch 8/200
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - bbox_output_iou_metric: 0.2722 - class_output_accuracy: 0.6609 - loss: 0.6389 - val_bbox_output_iou_metric: 0.3418 - val_class_output_accuracy: 0.6224 - val_loss: 0.6763
# Epoch 9/200
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - bbox_output_iou_metric: 0.2986 - class_output_accuracy: 0.6717 - loss: 0.6272 - val_bbox_output_iou_metric: 0.3617 - val_class_output_accuracy: 0.6224 - val_loss: 0.6695
# Epoch 10/200
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - bbox_output_iou_metric: 0.3211 - class_output_accuracy: 0.6735 - loss: 0.6161 - val_bbox_output_iou_metric: 0.3763 - val_class_output_accuracy: 0.6633 - val_loss: 0.6607
# Epoch 11/200
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - bbox_output_iou_metric: 0.3099 - class_output_accuracy: 0.7100 - loss: 0.6075 - val_bbox_output_iou_metric: 0.3733 - val_class_output_accuracy: 0.6837 - val_loss: 0.6461
# Epoch 12/200
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - bbox_output_iou_metric: 0.3350 - class_output_accuracy: 0.7598 - loss: 0.5997 - val_bbox_output_iou_metric: 0.3854 - val_class_output_accuracy: 0.7143 - val_loss: 0.6355
# Epoch 13/200
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - bbox_output_iou_metric: 0.3427 - class_output_accuracy: 0.7689 - loss: 0.5916 - val_bbox_output_iou_metric: 0.3826 - val_class_output_accuracy: 0.6939 - val_loss: 0.6341
# Epoch 14/200
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - bbox_output_iou_metric: 0.3361 - class_output_accuracy: 0.7500 - loss: 0.5815 - val_bbox_output_iou_metric: 0.3871 - val_class_output_accuracy: 0.6735 - val_loss: 0.6322
# Epoch 15/200
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - bbox_output_iou_metric: 0.3500 - class_output_accuracy: 0.7486 - loss: 0.5781 - val_bbox_output_iou_metric: 0.3909 - val_class_output_accuracy: 0.6735 - val_loss: 0.6266
# Epoch 16/200
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - bbox_output_iou_metric: 0.3518 - class_output_accuracy: 0.7185 - loss: 0.5700 - val_bbox_output_iou_metric: 0.3951 - val_class_output_accuracy: 0.6735 - val_loss: 0.6249
# Epoch 17/200
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - bbox_output_iou_metric: 0.3646 - class_output_accuracy: 0.7337 - loss: 0.5638 - val_bbox_output_iou_metric: 0.3974 - val_class_output_accuracy: 0.6939 - val_loss: 0.6138
# Epoch 18/200
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - bbox_output_iou_metric: 0.3540 - class_output_accuracy: 0.7788 - loss: 0.5538 - val_bbox_output_iou_metric: 0.3994 - val_class_output_accuracy: 0.7245 - val_loss: 0.6041
# Epoch 19/200
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - bbox_output_iou_metric: 0.3650 - class_output_accuracy: 0.7988 - loss: 0.5477 - val_bbox_output_iou_metric: 0.4009 - val_class_output_accuracy: 0.7347 - val_loss: 0.5990
# Epoch 20/200
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - bbox_output_iou_metric: 0.3638 - class_output_accuracy: 0.7942 - loss: 0.5427 - val_bbox_output_iou_metric: 0.4023 - val_class_output_accuracy: 0.7959 - val_loss: 0.5923
# Epoch 21/200
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - bbox_output_iou_metric: 0.3690 - class_output_accuracy: 0.8160 - loss: 0.5372 - val_bbox_output_iou_metric: 0.3991 - val_class_output_accuracy: 0.8367 - val_loss: 0.5823
# Epoch 22/200
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - bbox_output_iou_metric: 0.3828 - class_output_accuracy: 0.8261 - loss: 0.5312 - val_bbox_output_iou_metric: 0.4086 - val_class_output_accuracy: 0.8469 - val_loss: 0.5763
# Epoch 23/200
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - bbox_output_iou_metric: 0.3778 - class_output_accuracy: 0.8353 - loss: 0.5260 - val_bbox_output_iou_metric: 0.4068 - val_class_output_accuracy: 0.8469 - val_loss: 0.5714
# Epoch 24/200
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - bbox_output_iou_metric: 0.3730 - class_output_accuracy: 0.8371 - loss: 0.5203 - val_bbox_output_iou_metric: 0.4079 - val_class_output_accuracy: 0.8265 - val_loss: 0.5686
# Epoch 25/200
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - bbox_output_iou_metric: 0.3716 - class_output_accuracy: 0.8281 - loss: 0.5144 - val_bbox_output_iou_metric: 0.4160 - val_class_output_accuracy: 0.8061 - val_loss: 0.5671
# Epoch 26/200
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - bbox_output_iou_metric: 0.3867 - class_output_accuracy: 0.8340 - loss: 0.5080 - val_bbox_output_iou_metric: 0.4109 - val_class_output_accuracy: 0.8061 - val_loss: 0.5629
# Epoch 27/200
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - bbox_output_iou_metric: 0.3711 - class_output_accuracy: 0.8283 - loss: 0.5032 - val_bbox_output_iou_metric: 0.4181 - val_class_output_accuracy: 0.8061 - val_loss: 0.5589
# Epoch 28/200
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - bbox_output_iou_metric: 0.3758 - class_output_accuracy: 0.8299 - loss: 0.4972 - val_bbox_output_iou_metric: 0.4192 - val_class_output_accuracy: 0.8163 - val_loss: 0.5514
# Epoch 29/200
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - bbox_output_iou_metric: 0.3742 - class_output_accuracy: 0.8486 - loss: 0.4930 - val_bbox_output_iou_metric: 0.4185 - val_class_output_accuracy: 0.8776 - val_loss: 0.5413
# Epoch 30/200
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - bbox_output_iou_metric: 0.3838 - class_output_accuracy: 0.8655 - loss: 0.4924 - val_bbox_output_iou_metric: 0.4222 - val_class_output_accuracy: 0.8776 - val_loss: 0.5357
# Epoch 31/200
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - bbox_output_iou_metric: 0.3749 - class_output_accuracy: 0.8718 - loss: 0.4857 - val_bbox_output_iou_metric: 0.4257 - val_class_output_accuracy: 0.8673 - val_loss: 0.5332
# Epoch 32/200
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - bbox_output_iou_metric: 0.3969 - class_output_accuracy: 0.8584 - loss: 0.4796 - val_bbox_output_iou_metric: 0.4267 - val_class_output_accuracy: 0.8367 - val_loss: 0.5333
# Epoch 33/200
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - bbox_output_iou_metric: 0.3829 - class_output_accuracy: 0.8509 - loss: 0.4769 - val_bbox_output_iou_metric: 0.4242 - val_class_output_accuracy: 0.8673 - val_loss: 0.5278
# Epoch 34/200
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - bbox_output_iou_metric: 0.3910 - class_output_accuracy: 0.8565 - loss: 0.4707 - val_bbox_output_iou_metric: 0.4272 - val_class_output_accuracy: 0.8673 - val_loss: 0.5229
# Epoch 35/200
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - bbox_output_iou_metric: 0.3889 - class_output_accuracy: 0.8645 - loss: 0.4669 - val_bbox_output_iou_metric: 0.4289 - val_class_output_accuracy: 0.8878 - val_loss: 0.5159
# Epoch 36/200
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - bbox_output_iou_metric: 0.3899 - class_output_accuracy: 0.8831 - loss: 0.4614 - val_bbox_output_iou_metric: 0.4301 - val_class_output_accuracy: 0.8980 - val_loss: 0.5102
# Epoch 37/200
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - bbox_output_iou_metric: 0.4091 - class_output_accuracy: 0.8818 - loss: 0.4594 - val_bbox_output_iou_metric: 0.4309 - val_class_output_accuracy: 0.8878 - val_loss: 0.5096
# Epoch 38/200
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - bbox_output_iou_metric: 0.3812 - class_output_accuracy: 0.8540 - loss: 0.4574 - val_bbox_output_iou_metric: 0.4332 - val_class_output_accuracy: 0.8265 - val_loss: 0.5161
# Epoch 39/200
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - bbox_output_iou_metric: 0.3703 - class_output_accuracy: 0.8529 - loss: 0.4534 - val_bbox_output_iou_metric: 0.4297 - val_class_output_accuracy: 0.8265 - val_loss: 0.5116
# Epoch 40/200
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - bbox_output_iou_metric: 0.3800 - class_output_accuracy: 0.8654 - loss: 0.4456 - val_bbox_output_iou_metric: 0.4386 - val_class_output_accuracy: 0.8878 - val_loss: 0.4984
# Epoch 41/200
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - bbox_output_iou_metric: 0.4066 - class_output_accuracy: 0.8850 - loss: 0.4421 - val_bbox_output_iou_metric: 0.4373 - val_class_output_accuracy: 0.8980 - val_loss: 0.4912
# Epoch 42/200
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - bbox_output_iou_metric: 0.4046 - class_output_accuracy: 0.8885 - loss: 0.4404 - val_bbox_output_iou_metric: 0.4407 - val_class_output_accuracy: 0.9286 - val_loss: 0.4861
# Epoch 43/200
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - bbox_output_iou_metric: 0.4017 - class_output_accuracy: 0.8918 - loss: 0.4391 - val_bbox_output_iou_metric: 0.4396 - val_class_output_accuracy: 0.9286 - val_loss: 0.4819
# Epoch 44/200
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - bbox_output_iou_metric: 0.3957 - class_output_accuracy: 0.8951 - loss: 0.4344 - val_bbox_output_iou_metric: 0.4423 - val_class_output_accuracy: 0.8980 - val_loss: 0.4795
# Epoch 45/200
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - bbox_output_iou_metric: 0.3725 - class_output_accuracy: 0.8779 - loss: 0.4295 - val_bbox_output_iou_metric: 0.4440 - val_class_output_accuracy: 0.8878 - val_loss: 0.4783
# Epoch 46/200
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - bbox_output_iou_metric: 0.4004 - class_output_accuracy: 0.8809 - loss: 0.4280 - val_bbox_output_iou_metric: 0.4428 - val_class_output_accuracy: 0.8776 - val_loss: 0.4810
# Epoch 47/200
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - bbox_output_iou_metric: 0.4113 - class_output_accuracy: 0.8829 - loss: 0.4233 - val_bbox_output_iou_metric: 0.4465 - val_class_output_accuracy: 0.8980 - val_loss: 0.4709
# Epoch 48/200
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - bbox_output_iou_metric: 0.3962 - class_output_accuracy: 0.8842 - loss: 0.4210 - val_bbox_output_iou_metric: 0.4452 - val_class_output_accuracy: 0.9082 - val_loss: 0.4660
# Epoch 49/200
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - bbox_output_iou_metric: 0.4178 - class_output_accuracy: 0.8878 - loss: 0.4197 - val_bbox_output_iou_metric: 0.4477 - val_class_output_accuracy: 0.9388 - val_loss: 0.4620
# Epoch 50/200
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - bbox_output_iou_metric: 0.4030 - class_output_accuracy: 0.8987 - loss: 0.4139 - val_bbox_output_iou_metric: 0.4428 - val_class_output_accuracy: 0.9388 - val_loss: 0.4585
# Epoch 51/200
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - bbox_output_iou_metric: 0.4209 - class_output_accuracy: 0.8967 - loss: 0.4113 - val_bbox_output_iou_metric: 0.4507 - val_class_output_accuracy: 0.9388 - val_loss: 0.4553
# Epoch 52/200
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - bbox_output_iou_metric: 0.4044 - class_output_accuracy: 0.8975 - loss: 0.4071 - val_bbox_output_iou_metric: 0.4501 - val_class_output_accuracy: 0.9388 - val_loss: 0.4521
# Epoch 53/200
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - bbox_output_iou_metric: 0.4093 - class_output_accuracy: 0.8975 - loss: 0.4046 - val_bbox_output_iou_metric: 0.4510 - val_class_output_accuracy: 0.9388 - val_loss: 0.4489
# Epoch 54/200
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - bbox_output_iou_metric: 0.4211 - class_output_accuracy: 0.9027 - loss: 0.4013 - val_bbox_output_iou_metric: 0.4515 - val_class_output_accuracy: 0.9592 - val_loss: 0.4450
# Epoch 55/200
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - bbox_output_iou_metric: 0.3945 - class_output_accuracy: 0.9071 - loss: 0.3988 - val_bbox_output_iou_metric: 0.4560 - val_class_output_accuracy: 0.9388 - val_loss: 0.4428
# Epoch 56/200
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - bbox_output_iou_metric: 0.4025 - class_output_accuracy: 0.8956 - loss: 0.3971 - val_bbox_output_iou_metric: 0.4509 - val_class_output_accuracy: 0.9184 - val_loss: 0.4433
# Epoch 57/200
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - bbox_output_iou_metric: 0.4125 - class_output_accuracy: 0.8934 - loss: 0.3918 - val_bbox_output_iou_metric: 0.4560 - val_class_output_accuracy: 0.9286 - val_loss: 0.4393
# Epoch 58/200
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - bbox_output_iou_metric: 0.4210 - class_output_accuracy: 0.8979 - loss: 0.3919 - val_bbox_output_iou_metric: 0.4560 - val_class_output_accuracy: 0.9592 - val_loss: 0.4353
# Epoch 59/200
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - bbox_output_iou_metric: 0.4024 - class_output_accuracy: 0.9076 - loss: 0.3881 - val_bbox_output_iou_metric: 0.4567 - val_class_output_accuracy: 0.9592 - val_loss: 0.4317
# Epoch 60/200
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - bbox_output_iou_metric: 0.4169 - class_output_accuracy: 0.9089 - loss: 0.3845 - val_bbox_output_iou_metric: 0.4563 - val_class_output_accuracy: 0.9592 - val_loss: 0.4299
# Epoch 61/200
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - bbox_output_iou_metric: 0.4072 - class_output_accuracy: 0.9095 - loss: 0.3825 - val_bbox_output_iou_metric: 0.4587 - val_class_output_accuracy: 0.9286 - val_loss: 0.4297
# Epoch 62/200
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - bbox_output_iou_metric: 0.4249 - class_output_accuracy: 0.9063 - loss: 0.3793 - val_bbox_output_iou_metric: 0.4589 - val_class_output_accuracy: 0.9286 - val_loss: 0.4278
# Epoch 63/200
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - bbox_output_iou_metric: 0.4081 - class_output_accuracy: 0.9058 - loss: 0.3773 - val_bbox_output_iou_metric: 0.4613 - val_class_output_accuracy: 0.9286 - val_loss: 0.4240
# Epoch 64/200
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - bbox_output_iou_metric: 0.4129 - class_output_accuracy: 0.9109 - loss: 0.3751 - val_bbox_output_iou_metric: 0.4595 - val_class_output_accuracy: 0.9592 - val_loss: 0.4199
# Epoch 65/200
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - bbox_output_iou_metric: 0.3990 - class_output_accuracy: 0.9095 - loss: 0.3727 - val_bbox_output_iou_metric: 0.4552 - val_class_output_accuracy: 0.9592 - val_loss: 0.4164
# Epoch 66/200
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - bbox_output_iou_metric: 0.4162 - class_output_accuracy: 0.9150 - loss: 0.3685 - val_bbox_output_iou_metric: 0.4644 - val_class_output_accuracy: 0.9592 - val_loss: 0.4131
# Epoch 67/200
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - bbox_output_iou_metric: 0.4110 - class_output_accuracy: 0.9171 - loss: 0.3697 - val_bbox_output_iou_metric: 0.4629 - val_class_output_accuracy: 0.9592 - val_loss: 0.4105
# Epoch 68/200
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - bbox_output_iou_metric: 0.4337 - class_output_accuracy: 0.9095 - loss: 0.3641 - val_bbox_output_iou_metric: 0.4629 - val_class_output_accuracy: 0.9592 - val_loss: 0.4093
# Epoch 69/200
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - bbox_output_iou_metric: 0.4291 - class_output_accuracy: 0.9149 - loss: 0.3636 - val_bbox_output_iou_metric: 0.4654 - val_class_output_accuracy: 0.9592 - val_loss: 0.4077
# Epoch 70/200
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - bbox_output_iou_metric: 0.4040 - class_output_accuracy: 0.9108 - loss: 0.3605 - val_bbox_output_iou_metric: 0.4638 - val_class_output_accuracy: 0.9592 - val_loss: 0.4050
# Epoch 71/200
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - bbox_output_iou_metric: 0.4332 - class_output_accuracy: 0.9182 - loss: 0.3576 - val_bbox_output_iou_metric: 0.4596 - val_class_output_accuracy: 0.9592 - val_loss: 0.4021
# Epoch 72/200
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - bbox_output_iou_metric: 0.4172 - class_output_accuracy: 0.9228 - loss: 0.3550 - val_bbox_output_iou_metric: 0.4666 - val_class_output_accuracy: 0.9592 - val_loss: 0.4002
# Epoch 73/200
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - bbox_output_iou_metric: 0.4290 - class_output_accuracy: 0.9129 - loss: 0.3530 - val_bbox_output_iou_metric: 0.4681 - val_class_output_accuracy: 0.9592 - val_loss: 0.3973
# Epoch 74/200
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - bbox_output_iou_metric: 0.4186 - class_output_accuracy: 0.9092 - loss: 0.3523 - val_bbox_output_iou_metric: 0.4674 - val_class_output_accuracy: 0.9592 - val_loss: 0.3957
# Epoch 75/200
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - bbox_output_iou_metric: 0.4510 - class_output_accuracy: 0.9226 - loss: 0.3475 - val_bbox_output_iou_metric: 0.4671 - val_class_output_accuracy: 0.9592 - val_loss: 0.3932
# Epoch 76/200
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - bbox_output_iou_metric: 0.4253 - class_output_accuracy: 0.9151 - loss: 0.3456 - val_bbox_output_iou_metric: 0.4726 - val_class_output_accuracy: 0.9592 - val_loss: 0.3906
# Epoch 77/200
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - bbox_output_iou_metric: 0.4385 - class_output_accuracy: 0.9241 - loss: 0.3458 - val_bbox_output_iou_metric: 0.4705 - val_class_output_accuracy: 0.9592 - val_loss: 0.3886
# Epoch 78/200
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - bbox_output_iou_metric: 0.4239 - class_output_accuracy: 0.9222 - loss: 0.3429 - val_bbox_output_iou_metric: 0.4682 - val_class_output_accuracy: 0.9592 - val_loss: 0.3882
# Epoch 79/200
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - bbox_output_iou_metric: 0.4346 - class_output_accuracy: 0.9126 - loss: 0.3413 - val_bbox_output_iou_metric: 0.4713 - val_class_output_accuracy: 0.9592 - val_loss: 0.3857
# Epoch 80/200
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - bbox_output_iou_metric: 0.4178 - class_output_accuracy: 0.9172 - loss: 0.3390 - val_bbox_output_iou_metric: 0.4743 - val_class_output_accuracy: 0.9592 - val_loss: 0.3830
# Epoch 81/200
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - bbox_output_iou_metric: 0.4403 - class_output_accuracy: 0.9260 - loss: 0.3381 - val_bbox_output_iou_metric: 0.4708 - val_class_output_accuracy: 0.9592 - val_loss: 0.3816
# Epoch 82/200
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - bbox_output_iou_metric: 0.4284 - class_output_accuracy: 0.9172 - loss: 0.3358 - val_bbox_output_iou_metric: 0.4659 - val_class_output_accuracy: 0.9592 - val_loss: 0.3810
# Epoch 83/200
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - bbox_output_iou_metric: 0.4339 - class_output_accuracy: 0.9146 - loss: 0.3345 - val_bbox_output_iou_metric: 0.4749 - val_class_output_accuracy: 0.9592 - val_loss: 0.3797
# Epoch 84/200
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - bbox_output_iou_metric: 0.4407 - class_output_accuracy: 0.9212 - loss: 0.3316 - val_bbox_output_iou_metric: 0.4712 - val_class_output_accuracy: 0.9592 - val_loss: 0.3761
# Epoch 85/200
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - bbox_output_iou_metric: 0.4539 - class_output_accuracy: 0.9341 - loss: 0.3299 - val_bbox_output_iou_metric: 0.4716 - val_class_output_accuracy: 0.9592 - val_loss: 0.3741
# Epoch 86/200
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - bbox_output_iou_metric: 0.4194 - class_output_accuracy: 0.9345 - loss: 0.3296 - val_bbox_output_iou_metric: 0.4647 - val_class_output_accuracy: 0.9592 - val_loss: 0.3730
# Epoch 87/200
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - bbox_output_iou_metric: 0.4297 - class_output_accuracy: 0.9315 - loss: 0.3284 - val_bbox_output_iou_metric: 0.4739 - val_class_output_accuracy: 0.9592 - val_loss: 0.3714
# Epoch 88/200
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - bbox_output_iou_metric: 0.4510 - class_output_accuracy: 0.9180 - loss: 0.3258 - val_bbox_output_iou_metric: 0.4663 - val_class_output_accuracy: 0.9592 - val_loss: 0.3706
# Epoch 89/200
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - bbox_output_iou_metric: 0.4473 - class_output_accuracy: 0.9249 - loss: 0.3235 - val_bbox_output_iou_metric: 0.4709 - val_class_output_accuracy: 0.9592 - val_loss: 0.3674
# Epoch 90/200
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - bbox_output_iou_metric: 0.4219 - class_output_accuracy: 0.9298 - loss: 0.3227 - val_bbox_output_iou_metric: 0.4721 - val_class_output_accuracy: 0.9592 - val_loss: 0.3660
# Epoch 91/200
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - bbox_output_iou_metric: 0.4367 - class_output_accuracy: 0.9347 - loss: 0.3191 - val_bbox_output_iou_metric: 0.4726 - val_class_output_accuracy: 0.9592 - val_loss: 0.3646
# Epoch 92/200
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - bbox_output_iou_metric: 0.4272 - class_output_accuracy: 0.9302 - loss: 0.3184 - val_bbox_output_iou_metric: 0.4779 - val_class_output_accuracy: 0.9592 - val_loss: 0.3633
# Epoch 93/200
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - bbox_output_iou_metric: 0.4304 - class_output_accuracy: 0.9330 - loss: 0.3164 - val_bbox_output_iou_metric: 0.4674 - val_class_output_accuracy: 0.9592 - val_loss: 0.3611
# Epoch 94/200
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - bbox_output_iou_metric: 0.4272 - class_output_accuracy: 0.9307 - loss: 0.3144 - val_bbox_output_iou_metric: 0.4703 - val_class_output_accuracy: 0.9592 - val_loss: 0.3602
# Epoch 95/200
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - bbox_output_iou_metric: 0.4565 - class_output_accuracy: 0.9190 - loss: 0.3119 - val_bbox_output_iou_metric: 0.4806 - val_class_output_accuracy: 0.9592 - val_loss: 0.3579
# Epoch 96/200
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - bbox_output_iou_metric: 0.4684 - class_output_accuracy: 0.9367 - loss: 0.3114 - val_bbox_output_iou_metric: 0.4758 - val_class_output_accuracy: 0.9592 - val_loss: 0.3551
# Epoch 97/200
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - bbox_output_iou_metric: 0.4374 - class_output_accuracy: 0.9458 - loss: 0.3107 - val_bbox_output_iou_metric: 0.4736 - val_class_output_accuracy: 0.9694 - val_loss: 0.3538
# Epoch 98/200
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - bbox_output_iou_metric: 0.4364 - class_output_accuracy: 0.9503 - loss: 0.3100 - val_bbox_output_iou_metric: 0.4822 - val_class_output_accuracy: 0.9694 - val_loss: 0.3518
# Epoch 99/200
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - bbox_output_iou_metric: 0.4492 - class_output_accuracy: 0.9454 - loss: 0.3057 - val_bbox_output_iou_metric: 0.4715 - val_class_output_accuracy: 0.9592 - val_loss: 0.3509
# Epoch 100/200
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - bbox_output_iou_metric: 0.4317 - class_output_accuracy: 0.9347 - loss: 0.3045 - val_bbox_output_iou_metric: 0.4733 - val_class_output_accuracy: 0.9592 - val_loss: 0.3497
# Epoch 101/200
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - bbox_output_iou_metric: 0.4449 - class_output_accuracy: 0.9314 - loss: 0.3056 - val_bbox_output_iou_metric: 0.4740 - val_class_output_accuracy: 0.9592 - val_loss: 0.3476
# Epoch 102/200
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - bbox_output_iou_metric: 0.4425 - class_output_accuracy: 0.9412 - loss: 0.2997 - val_bbox_output_iou_metric: 0.4772 - val_class_output_accuracy: 0.9592 - val_loss: 0.3463
# Epoch 103/200
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - bbox_output_iou_metric: 0.4207 - class_output_accuracy: 0.9404 - loss: 0.2997 - val_bbox_output_iou_metric: 0.4787 - val_class_output_accuracy: 0.9694 - val_loss: 0.3443
# Epoch 104/200
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - bbox_output_iou_metric: 0.4440 - class_output_accuracy: 0.9429 - loss: 0.2972 - val_bbox_output_iou_metric: 0.4854 - val_class_output_accuracy: 0.9592 - val_loss: 0.3433
# Epoch 105/200
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - bbox_output_iou_metric: 0.4348 - class_output_accuracy: 0.9301 - loss: 0.2987 - val_bbox_output_iou_metric: 0.4802 - val_class_output_accuracy: 0.9592 - val_loss: 0.3425
# Epoch 106/200
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - bbox_output_iou_metric: 0.4461 - class_output_accuracy: 0.9332 - loss: 0.2963 - val_bbox_output_iou_metric: 0.4712 - val_class_output_accuracy: 0.9592 - val_loss: 0.3415
# Epoch 107/200
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - bbox_output_iou_metric: 0.4526 - class_output_accuracy: 0.9309 - loss: 0.2940 - val_bbox_output_iou_metric: 0.4860 - val_class_output_accuracy: 0.9592 - val_loss: 0.3400
# Epoch 108/200
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - bbox_output_iou_metric: 0.4461 - class_output_accuracy: 0.9398 - loss: 0.2916 - val_bbox_output_iou_metric: 0.4753 - val_class_output_accuracy: 0.9694 - val_loss: 0.3378
# Epoch 109/200
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - bbox_output_iou_metric: 0.4467 - class_output_accuracy: 0.9520 - loss: 0.2916 - val_bbox_output_iou_metric: 0.4789 - val_class_output_accuracy: 0.9694 - val_loss: 0.3361
# Epoch 110/200
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - bbox_output_iou_metric: 0.4603 - class_output_accuracy: 0.9468 - loss: 0.2910 - val_bbox_output_iou_metric: 0.4772 - val_class_output_accuracy: 0.9694 - val_loss: 0.3354
# Epoch 111/200
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - bbox_output_iou_metric: 0.4414 - class_output_accuracy: 0.9532 - loss: 0.2870 - val_bbox_output_iou_metric: 0.4774 - val_class_output_accuracy: 0.9694 - val_loss: 0.3341
# Epoch 112/200
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - bbox_output_iou_metric: 0.4464 - class_output_accuracy: 0.9494 - loss: 0.2867 - val_bbox_output_iou_metric: 0.4827 - val_class_output_accuracy: 0.9694 - val_loss: 0.3328
# Epoch 113/200
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - bbox_output_iou_metric: 0.4494 - class_output_accuracy: 0.9492 - loss: 0.2859 - val_bbox_output_iou_metric: 0.4788 - val_class_output_accuracy: 0.9694 - val_loss: 0.3314
# Epoch 114/200
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - bbox_output_iou_metric: 0.4366 - class_output_accuracy: 0.9486 - loss: 0.2852 - val_bbox_output_iou_metric: 0.4806 - val_class_output_accuracy: 0.9694 - val_loss: 0.3297
# Epoch 115/200
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - bbox_output_iou_metric: 0.4397 - class_output_accuracy: 0.9498 - loss: 0.2835 - val_bbox_output_iou_metric: 0.4835 - val_class_output_accuracy: 0.9592 - val_loss: 0.3296
# Epoch 116/200
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - bbox_output_iou_metric: 0.4394 - class_output_accuracy: 0.9317 - loss: 0.2820 - val_bbox_output_iou_metric: 0.4800 - val_class_output_accuracy: 0.9592 - val_loss: 0.3297
# Epoch 117/200
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - bbox_output_iou_metric: 0.4473 - class_output_accuracy: 0.9313 - loss: 0.2811 - val_bbox_output_iou_metric: 0.4754 - val_class_output_accuracy: 0.9592 - val_loss: 0.3276
# Epoch 118/200
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - bbox_output_iou_metric: 0.4531 - class_output_accuracy: 0.9312 - loss: 0.2802 - val_bbox_output_iou_metric: 0.4752 - val_class_output_accuracy: 0.9592 - val_loss: 0.3266
# Epoch 119/200
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - bbox_output_iou_metric: 0.4673 - class_output_accuracy: 0.9372 - loss: 0.2789 - val_bbox_output_iou_metric: 0.4816 - val_class_output_accuracy: 0.9592 - val_loss: 0.3249
# Epoch 120/200
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - bbox_output_iou_metric: 0.4640 - class_output_accuracy: 0.9466 - loss: 0.2774 - val_bbox_output_iou_metric: 0.4674 - val_class_output_accuracy: 0.9694 - val_loss: 0.3228
# Epoch 121/200
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - bbox_output_iou_metric: 0.4639 - class_output_accuracy: 0.9513 - loss: 0.2762 - val_bbox_output_iou_metric: 0.4858 - val_class_output_accuracy: 0.9592 - val_loss: 0.3220
# Epoch 122/200
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - bbox_output_iou_metric: 0.4536 - class_output_accuracy: 0.9569 - loss: 0.2774 - val_bbox_output_iou_metric: 0.4735 - val_class_output_accuracy: 0.9694 - val_loss: 0.3208
# Epoch 123/200
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - bbox_output_iou_metric: 0.4588 - class_output_accuracy: 0.9469 - loss: 0.2756 - val_bbox_output_iou_metric: 0.4867 - val_class_output_accuracy: 0.9694 - val_loss: 0.3202
# Epoch 124/200
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - bbox_output_iou_metric: 0.4696 - class_output_accuracy: 0.9449 - loss: 0.2719 - val_bbox_output_iou_metric: 0.4864 - val_class_output_accuracy: 0.9592 - val_loss: 0.3192
# Epoch 125/200
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - bbox_output_iou_metric: 0.4749 - class_output_accuracy: 0.9311 - loss: 0.2751 - val_bbox_output_iou_metric: 0.4750 - val_class_output_accuracy: 0.9592 - val_loss: 0.3212
# Epoch 126/200
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - bbox_output_iou_metric: 0.4533 - class_output_accuracy: 0.9324 - loss: 0.2724 - val_bbox_output_iou_metric: 0.4758 - val_class_output_accuracy: 0.9694 - val_loss: 0.3162
# Epoch 127/200
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - bbox_output_iou_metric: 0.4487 - class_output_accuracy: 0.9551 - loss: 0.2687 - val_bbox_output_iou_metric: 0.4800 - val_class_output_accuracy: 0.9694 - val_loss: 0.3148
# Epoch 128/200
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - bbox_output_iou_metric: 0.4840 - class_output_accuracy: 0.9572 - loss: 0.2682 - val_bbox_output_iou_metric: 0.4791 - val_class_output_accuracy: 0.9592 - val_loss: 0.3137
# Epoch 129/200
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - bbox_output_iou_metric: 0.4574 - class_output_accuracy: 0.9561 - loss: 0.2681 - val_bbox_output_iou_metric: 0.4814 - val_class_output_accuracy: 0.9694 - val_loss: 0.3125
# Epoch 130/200
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - bbox_output_iou_metric: 0.4450 - class_output_accuracy: 0.9509 - loss: 0.2667 - val_bbox_output_iou_metric: 0.4672 - val_class_output_accuracy: 0.9694 - val_loss: 0.3123
# Epoch 131/200
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - bbox_output_iou_metric: 0.4532 - class_output_accuracy: 0.9518 - loss: 0.2661 - val_bbox_output_iou_metric: 0.4744 - val_class_output_accuracy: 0.9694 - val_loss: 0.3105
# Epoch 132/200
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - bbox_output_iou_metric: 0.4701 - class_output_accuracy: 0.9518 - loss: 0.2651 - val_bbox_output_iou_metric: 0.4680 - val_class_output_accuracy: 0.9694 - val_loss: 0.3106
# Epoch 133/200
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - bbox_output_iou_metric: 0.4398 - class_output_accuracy: 0.9514 - loss: 0.2644 - val_bbox_output_iou_metric: 0.4726 - val_class_output_accuracy: 0.9694 - val_loss: 0.3085
# Epoch 134/200
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - bbox_output_iou_metric: 0.4678 - class_output_accuracy: 0.9547 - loss: 0.2620 - val_bbox_output_iou_metric: 0.4680 - val_class_output_accuracy: 0.9694 - val_loss: 0.3091
# Epoch 135/200
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - bbox_output_iou_metric: 0.4720 - class_output_accuracy: 0.9537 - loss: 0.2620 - val_bbox_output_iou_metric: 0.4722 - val_class_output_accuracy: 0.9694 - val_loss: 0.3064
# Epoch 136/200
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - bbox_output_iou_metric: 0.4526 - class_output_accuracy: 0.9502 - loss: 0.2619 - val_bbox_output_iou_metric: 0.4809 - val_class_output_accuracy: 0.9694 - val_loss: 0.3061
# Epoch 137/200
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - bbox_output_iou_metric: 0.4716 - class_output_accuracy: 0.9536 - loss: 0.2591 - val_bbox_output_iou_metric: 0.4788 - val_class_output_accuracy: 0.9694 - val_loss: 0.3048
# Epoch 138/200
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - bbox_output_iou_metric: 0.4766 - class_output_accuracy: 0.9489 - loss: 0.2599 - val_bbox_output_iou_metric: 0.4893 - val_class_output_accuracy: 0.9694 - val_loss: 0.3034
# Epoch 139/200
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - bbox_output_iou_metric: 0.4863 - class_output_accuracy: 0.9514 - loss: 0.2577 - val_bbox_output_iou_metric: 0.4757 - val_class_output_accuracy: 0.9694 - val_loss: 0.3030
# Epoch 140/200
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - bbox_output_iou_metric: 0.4654 - class_output_accuracy: 0.9551 - loss: 0.2555 - val_bbox_output_iou_metric: 0.4773 - val_class_output_accuracy: 0.9694 - val_loss: 0.3020
# Epoch 141/200
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - bbox_output_iou_metric: 0.4686 - class_output_accuracy: 0.9467 - loss: 0.2562 - val_bbox_output_iou_metric: 0.4807 - val_class_output_accuracy: 0.9694 - val_loss: 0.3007
# Epoch 142/200
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - bbox_output_iou_metric: 0.4621 - class_output_accuracy: 0.9538 - loss: 0.2542 - val_bbox_output_iou_metric: 0.4759 - val_class_output_accuracy: 0.9694 - val_loss: 0.3000
# Epoch 143/200
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - bbox_output_iou_metric: 0.4469 - class_output_accuracy: 0.9531 - loss: 0.2553 - val_bbox_output_iou_metric: 0.4800 - val_class_output_accuracy: 0.9694 - val_loss: 0.2986
# Epoch 144/200
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - bbox_output_iou_metric: 0.4752 - class_output_accuracy: 0.9549 - loss: 0.2505 - val_bbox_output_iou_metric: 0.4931 - val_class_output_accuracy: 0.9694 - val_loss: 0.2976
# Epoch 145/200
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - bbox_output_iou_metric: 0.4767 - class_output_accuracy: 0.9557 - loss: 0.2504 - val_bbox_output_iou_metric: 0.4712 - val_class_output_accuracy: 0.9694 - val_loss: 0.2973
# Epoch 146/200
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - bbox_output_iou_metric: 0.4768 - class_output_accuracy: 0.9539 - loss: 0.2499 - val_bbox_output_iou_metric: 0.4865 - val_class_output_accuracy: 0.9694 - val_loss: 0.2961
# Epoch 147/200
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - bbox_output_iou_metric: 0.4582 - class_output_accuracy: 0.9541 - loss: 0.2477 - val_bbox_output_iou_metric: 0.4907 - val_class_output_accuracy: 0.9694 - val_loss: 0.2953
# Epoch 148/200
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - bbox_output_iou_metric: 0.4498 - class_output_accuracy: 0.9521 - loss: 0.2498 - val_bbox_output_iou_metric: 0.4735 - val_class_output_accuracy: 0.9694 - val_loss: 0.2962
# Epoch 149/200
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - bbox_output_iou_metric: 0.4954 - class_output_accuracy: 0.9531 - loss: 0.2483 - val_bbox_output_iou_metric: 0.4891 - val_class_output_accuracy: 0.9694 - val_loss: 0.2941
# Epoch 150/200
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - bbox_output_iou_metric: 0.4856 - class_output_accuracy: 0.9555 - loss: 0.2483 - val_bbox_output_iou_metric: 0.4782 - val_class_output_accuracy: 0.9694 - val_loss: 0.2933
# Epoch 151/200
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - bbox_output_iou_metric: 0.4739 - class_output_accuracy: 0.9565 - loss: 0.2449 - val_bbox_output_iou_metric: 0.4824 - val_class_output_accuracy: 0.9694 - val_loss: 0.2918
# Epoch 152/200
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - bbox_output_iou_metric: 0.4619 - class_output_accuracy: 0.9577 - loss: 0.2431 - val_bbox_output_iou_metric: 0.4781 - val_class_output_accuracy: 0.9694 - val_loss: 0.2918
# Epoch 153/200
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - bbox_output_iou_metric: 0.4347 - class_output_accuracy: 0.9539 - loss: 0.2436 - val_bbox_output_iou_metric: 0.4766 - val_class_output_accuracy: 0.9694 - val_loss: 0.2900
# Epoch 154/200
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - bbox_output_iou_metric: 0.4866 - class_output_accuracy: 0.9497 - loss: 0.2454 - val_bbox_output_iou_metric: 0.4830 - val_class_output_accuracy: 0.9694 - val_loss: 0.2906
# Epoch 155/200
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - bbox_output_iou_metric: 0.4841 - class_output_accuracy: 0.9592 - loss: 0.2424 - val_bbox_output_iou_metric: 0.4819 - val_class_output_accuracy: 0.9694 - val_loss: 0.2892
# Epoch 156/200
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - bbox_output_iou_metric: 0.4793 - class_output_accuracy: 0.9546 - loss: 0.2417 - val_bbox_output_iou_metric: 0.4839 - val_class_output_accuracy: 0.9694 - val_loss: 0.2894
# Epoch 157/200
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - bbox_output_iou_metric: 0.4849 - class_output_accuracy: 0.9547 - loss: 0.2436 - val_bbox_output_iou_metric: 0.4902 - val_class_output_accuracy: 0.9694 - val_loss: 0.2883
# Epoch 158/200
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - bbox_output_iou_metric: 0.4661 - class_output_accuracy: 0.9568 - loss: 0.2403 - val_bbox_output_iou_metric: 0.4845 - val_class_output_accuracy: 0.9694 - val_loss: 0.2871
# Epoch 159/200
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - bbox_output_iou_metric: 0.4779 - class_output_accuracy: 0.9591 - loss: 0.2384 - val_bbox_output_iou_metric: 0.4841 - val_class_output_accuracy: 0.9694 - val_loss: 0.2868
# Epoch 160/200
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - bbox_output_iou_metric: 0.4927 - class_output_accuracy: 0.9571 - loss: 0.2371 - val_bbox_output_iou_metric: 0.4907 - val_class_output_accuracy: 0.9694 - val_loss: 0.2853
# Epoch 161/200
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - bbox_output_iou_metric: 0.4917 - class_output_accuracy: 0.9556 - loss: 0.2357 - val_bbox_output_iou_metric: 0.4832 - val_class_output_accuracy: 0.9694 - val_loss: 0.2851
# Epoch 162/200
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - bbox_output_iou_metric: 0.4891 - class_output_accuracy: 0.9571 - loss: 0.2362 - val_bbox_output_iou_metric: 0.4787 - val_class_output_accuracy: 0.9592 - val_loss: 0.2853
# Epoch 163/200
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - bbox_output_iou_metric: 0.4595 - class_output_accuracy: 0.9567 - loss: 0.2371 - val_bbox_output_iou_metric: 0.4754 - val_class_output_accuracy: 0.9694 - val_loss: 0.2839
# Epoch 164/200
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - bbox_output_iou_metric: 0.4646 - class_output_accuracy: 0.9540 - loss: 0.2361 - val_bbox_output_iou_metric: 0.4823 - val_class_output_accuracy: 0.9694 - val_loss: 0.2835
# Epoch 165/200
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - bbox_output_iou_metric: 0.4964 - class_output_accuracy: 0.9619 - loss: 0.2346 - val_bbox_output_iou_metric: 0.4848 - val_class_output_accuracy: 0.9694 - val_loss: 0.2826
# Epoch 166/200
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - bbox_output_iou_metric: 0.4667 - class_output_accuracy: 0.9624 - loss: 0.2322 - val_bbox_output_iou_metric: 0.4843 - val_class_output_accuracy: 0.9694 - val_loss: 0.2815
# Epoch 167/200
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - bbox_output_iou_metric: 0.4841 - class_output_accuracy: 0.9568 - loss: 0.2326 - val_bbox_output_iou_metric: 0.4913 - val_class_output_accuracy: 0.9592 - val_loss: 0.2811
# Epoch 168/200
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - bbox_output_iou_metric: 0.4744 - class_output_accuracy: 0.9563 - loss: 0.2312 - val_bbox_output_iou_metric: 0.4692 - val_class_output_accuracy: 0.9694 - val_loss: 0.2810
# Epoch 169/200
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - bbox_output_iou_metric: 0.4842 - class_output_accuracy: 0.9591 - loss: 0.2320 - val_bbox_output_iou_metric: 0.4880 - val_class_output_accuracy: 0.9694 - val_loss: 0.2794
# Epoch 170/200
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - bbox_output_iou_metric: 0.4952 - class_output_accuracy: 0.9623 - loss: 0.2295 - val_bbox_output_iou_metric: 0.4820 - val_class_output_accuracy: 0.9694 - val_loss: 0.2794
# Epoch 171/200
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - bbox_output_iou_metric: 0.4705 - class_output_accuracy: 0.9615 - loss: 0.2303 - val_bbox_output_iou_metric: 0.4821 - val_class_output_accuracy: 0.9694 - val_loss: 0.2785
# Epoch 172/200
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - bbox_output_iou_metric: 0.4772 - class_output_accuracy: 0.9558 - loss: 0.2295 - val_bbox_output_iou_metric: 0.4910 - val_class_output_accuracy: 0.9694 - val_loss: 0.2786
# Epoch 173/200
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - bbox_output_iou_metric: 0.4723 - class_output_accuracy: 0.9569 - loss: 0.2282 - val_bbox_output_iou_metric: 0.4799 - val_class_output_accuracy: 0.9694 - val_loss: 0.2783
# Epoch 174/200
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - bbox_output_iou_metric: 0.4829 - class_output_accuracy: 0.9566 - loss: 0.2280 - val_bbox_output_iou_metric: 0.4930 - val_class_output_accuracy: 0.9694 - val_loss: 0.2774
# Epoch 175/200
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - bbox_output_iou_metric: 0.4906 - class_output_accuracy: 0.9547 - loss: 0.2291 - val_bbox_output_iou_metric: 0.4784 - val_class_output_accuracy: 0.9694 - val_loss: 0.2764
# Epoch 176/200
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - bbox_output_iou_metric: 0.5066 - class_output_accuracy: 0.9575 - loss: 0.2258 - val_bbox_output_iou_metric: 0.4927 - val_class_output_accuracy: 0.9694 - val_loss: 0.2758
# Epoch 177/200
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - bbox_output_iou_metric: 0.4719 - class_output_accuracy: 0.9608 - loss: 0.2231 - val_bbox_output_iou_metric: 0.4849 - val_class_output_accuracy: 0.9694 - val_loss: 0.2748
# Epoch 178/200
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - bbox_output_iou_metric: 0.4787 - class_output_accuracy: 0.9640 - loss: 0.2249 - val_bbox_output_iou_metric: 0.4819 - val_class_output_accuracy: 0.9694 - val_loss: 0.2737
# Epoch 179/200
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - bbox_output_iou_metric: 0.4985 - class_output_accuracy: 0.9652 - loss: 0.2220 - val_bbox_output_iou_metric: 0.4891 - val_class_output_accuracy: 0.9694 - val_loss: 0.2735
# Epoch 180/200
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - bbox_output_iou_metric: 0.4814 - class_output_accuracy: 0.9625 - loss: 0.2223 - val_bbox_output_iou_metric: 0.4805 - val_class_output_accuracy: 0.9694 - val_loss: 0.2733
# Epoch 181/200
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - bbox_output_iou_metric: 0.4692 - class_output_accuracy: 0.9595 - loss: 0.2227 - val_bbox_output_iou_metric: 0.4702 - val_class_output_accuracy: 0.9694 - val_loss: 0.2735
# Epoch 182/200
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - bbox_output_iou_metric: 0.4764 - class_output_accuracy: 0.9653 - loss: 0.2203 - val_bbox_output_iou_metric: 0.4719 - val_class_output_accuracy: 0.9694 - val_loss: 0.2717
# Epoch 183/200
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - bbox_output_iou_metric: 0.4603 - class_output_accuracy: 0.9632 - loss: 0.2216 - val_bbox_output_iou_metric: 0.4789 - val_class_output_accuracy: 0.9694 - val_loss: 0.2715
# Epoch 184/200
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - bbox_output_iou_metric: 0.4794 - class_output_accuracy: 0.9634 - loss: 0.2216 - val_bbox_output_iou_metric: 0.4834 - val_class_output_accuracy: 0.9694 - val_loss: 0.2714
# Epoch 185/200
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - bbox_output_iou_metric: 0.4766 - class_output_accuracy: 0.9568 - loss: 0.2217 - val_bbox_output_iou_metric: 0.4801 - val_class_output_accuracy: 0.9694 - val_loss: 0.2719
# Epoch 186/200
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - bbox_output_iou_metric: 0.4556 - class_output_accuracy: 0.9600 - loss: 0.2200 - val_bbox_output_iou_metric: 0.4900 - val_class_output_accuracy: 0.9694 - val_loss: 0.2696
# Epoch 187/200
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - bbox_output_iou_metric: 0.4781 - class_output_accuracy: 0.9571 - loss: 0.2180 - val_bbox_output_iou_metric: 0.4911 - val_class_output_accuracy: 0.9592 - val_loss: 0.2694
# Epoch 188/200
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - bbox_output_iou_metric: 0.4661 - class_output_accuracy: 0.9600 - loss: 0.2177 - val_bbox_output_iou_metric: 0.4763 - val_class_output_accuracy: 0.9694 - val_loss: 0.2689
# Epoch 189/200
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - bbox_output_iou_metric: 0.4785 - class_output_accuracy: 0.9609 - loss: 0.2187 - val_bbox_output_iou_metric: 0.4953 - val_class_output_accuracy: 0.9694 - val_loss: 0.2673
# Epoch 190/200
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - bbox_output_iou_metric: 0.4850 - class_output_accuracy: 0.9643 - loss: 0.2179 - val_bbox_output_iou_metric: 0.4740 - val_class_output_accuracy: 0.9694 - val_loss: 0.2684
# Epoch 191/200
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - bbox_output_iou_metric: 0.4921 - class_output_accuracy: 0.9646 - loss: 0.2141 - val_bbox_output_iou_metric: 0.4956 - val_class_output_accuracy: 0.9694 - val_loss: 0.2666
# Epoch 192/200
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - bbox_output_iou_metric: 0.4595 - class_output_accuracy: 0.9645 - loss: 0.2162 - val_bbox_output_iou_metric: 0.4886 - val_class_output_accuracy: 0.9694 - val_loss: 0.2657
# Epoch 193/200
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - bbox_output_iou_metric: 0.4708 - class_output_accuracy: 0.9650 - loss: 0.2134 - val_bbox_output_iou_metric: 0.4800 - val_class_output_accuracy: 0.9694 - val_loss: 0.2658
# Epoch 194/200
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - bbox_output_iou_metric: 0.4914 - class_output_accuracy: 0.9652 - loss: 0.2120 - val_bbox_output_iou_metric: 0.4923 - val_class_output_accuracy: 0.9694 - val_loss: 0.2649
# Epoch 195/200
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - bbox_output_iou_metric: 0.4796 - class_output_accuracy: 0.9629 - loss: 0.2148 - val_bbox_output_iou_metric: 0.4854 - val_class_output_accuracy: 0.9694 - val_loss: 0.2642
# Epoch 196/200
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - bbox_output_iou_metric: 0.4943 - class_output_accuracy: 0.9634 - loss: 0.2144 - val_bbox_output_iou_metric: 0.4827 - val_class_output_accuracy: 0.9694 - val_loss: 0.2645
# Epoch 197/200
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - bbox_output_iou_metric: 0.4837 - class_output_accuracy: 0.9600 - loss: 0.2135 - val_bbox_output_iou_metric: 0.4898 - val_class_output_accuracy: 0.9592 - val_loss: 0.2630
# Epoch 198/200
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - bbox_output_iou_metric: 0.4879 - class_output_accuracy: 0.9620 - loss: 0.2112 - val_bbox_output_iou_metric: 0.4884 - val_class_output_accuracy: 0.9694 - val_loss: 0.2631
# Epoch 199/200
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - bbox_output_iou_metric: 0.4874 - class_output_accuracy: 0.9642 - loss: 0.2108 - val_bbox_output_iou_metric: 0.4876 - val_class_output_accuracy: 0.9694 - val_loss: 0.2622
# Epoch 200/200
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - bbox_output_iou_metric: 0.4957 - class_output_accuracy: 0.9645 - loss: 0.2107 - val_bbox_output_iou_metric: 0.4882 - val_class_output_accuracy: 0.9694 - val_loss: 0.2622

# %%
import matplotlib.pyplot as plt
plt.figure(figsize=(12, 6))
plt.plot(history.history['class_output_accuracy'], label='Training Accuracy')
plt.plot(history.history['val_class_output_accuracy'], label='Validation Accuracy')
plt.title('Model Accuracy Over Epochs')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend()
plt.grid()
plt.show()

# Eğitim ve doğrulama kaybı (loss)
plt.figure(figsize=(12, 6))
plt.plot(history.history['loss'], label='Training Loss')
plt.plot(history.history['val_loss'], label='Validation Loss')
plt.title('Model Loss Over Epochs')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.grid()
plt.show()

# %%
import matplotlib.pyplot as plt

# IoU Skorları (Eğitim ve Doğrulama)
train_iou = history.history['bbox_output_iou_metric']
val_iou = history.history['val_bbox_output_iou_metric']

# Grafik
plt.figure(figsize=(10, 6))
plt.plot(train_iou, label='Training IoU')
plt.plot(val_iou, label='Validation IoU')
plt.title('IoU Scores During Training')
plt.xlabel('Epochs')
plt.ylabel('IoU')
plt.legend()
plt.grid()
plt.show()

# %%
y_bbox_pred = model.predict(X)[1]
iou_scores = []

for true_bbox, pred_bbox in zip(y_bbox, y_bbox_pred):
    intersection = np.maximum(0, np.minimum(true_bbox[2], pred_bbox[2]) - np.maximum(true_bbox[0], pred_bbox[0])) * \
                   np.maximum(0, np.minimum(true_bbox[3], pred_bbox[3]) - np.maximum(true_bbox[1], pred_bbox[1]))
    union = (true_bbox[2] - true_bbox[0]) * (true_bbox[3] - true_bbox[1]) + \
            (pred_bbox[2] - pred_bbox[0]) * (pred_bbox[3] - pred_bbox[1]) - intersection
    iou_scores.append(intersection / (union + 1e-6))

mean_iou = np.mean(iou_scores)
print(f"Mean IoU: {mean_iou}")
# Out:
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 11s 269ms/step
# Mean IoU: 0.48711681434685694

# %%
import matplotlib.pyplot as plt
import cv2

# Test verisini yükle
test_image_path = '/kaggle/input/sssasdasd/train/00000000_jpg.rf.2bf797cb649fe386144a53f4b982ee4d.jpg'  # Test görseli yolu
test_image = cv2.imread(test_image_path)

# Görseli ön işleme (aynı şekilde eğitildiği gibi)
test_image_resized = cv2.resize(test_image, (224, 224)) / 255.0  # Normalize et
test_image_resized = np.expand_dims(test_image_resized, axis=0)  # Batch boyutunu ekle

# Modeli kullanarak tahmin yap
class_pred, bbox_pred = model.predict(test_image_resized)

# Sınıf tahminini al (0 veya 1)
predicted_class = 'fork' if class_pred > 0.5 else 'spoon'

# Bounding box tahmini (normalize edilmiş)
predicted_bbox = bbox_pred[0]  # 4 koordinat (xmin, ymin, xmax, ymax)

# Görseli orijinal boyutuna getirmek için yeniden boyutlandır
test_image_resized = cv2.resize(test_image_resized[0], (test_image.shape[1], test_image.shape[0]))

# Bounding box'ı görselleştir
xmin, ymin, xmax, ymax = predicted_bbox * np.array([test_image.shape[1], test_image.shape[0], test_image.shape[1], test_image.shape[0]])

# Görseldeki bounding box'ı çiz
cv2.rectangle(test_image, (int(xmin), int(ymin)), (int(xmax), int(ymax)), (0, 255, 0), 2)

# Görseli ve sınıf tahminini göster
plt.imshow(cv2.cvtColor(test_image, cv2.COLOR_BGR2RGB))
plt.title(f'Predicted Class: {predicted_class}')
plt.show()
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 981ms/step

# %%
# Modeli H5 formatında kaydet
model.save('model.h5')

# %%
import tensorflow as tf

# Modeli yükle
model = tf.keras.models.load_model('model.h5')

# TFLiteConverter kullanarak modelin Lite formatına dönüştürülmesi
converter = tf.lite.TFLiteConverter.from_keras_model(model)

# Modeli .tflite formatında kaydet
tflite_model = converter.convert()

# TFLite modelini dosyaya kaydet
with open('model.tflite', 'wb') as f:
    f.write(tflite_model)
# Out:
# Saved artifact at '/tmp/tmpjlahho2j'. The following endpoints are available:
#
# * Endpoint 'serve'
#   args_0 (POSITIONAL_ONLY): TensorSpec(shape=(None, 224, 224, 3), dtype=tf.float32, name='input_layer_2')
# Output Type:
#   List[TensorSpec(shape=(None, 1), dtype=tf.float32, name=None), TensorSpec(shape=(None, 4), dtype=tf.float32, name=None)]
# Captures:
#   139296539387408: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139296539391456: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139296539390400: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139296539385648: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139296539386352: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139296539387056: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139296539385472: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139296539380896: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139296539381248: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139296539391808: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139296539388464: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139296539381952: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139296539381424: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139296539393392: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139296539383536: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139296540940720: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139296540948816: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139296540945120: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139296540946352: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139296541181376: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139296541192816: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139296541189120: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139296541195984: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139296541188592: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139296538252688: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139296538248288: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139296538250752: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139296538257264: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139296538256208: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139296538259552: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139296538253040: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139296538259904: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139296538247232: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139296538188208: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139296538259200: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139296538254976: TensorSpec(shape=(), dtype=tf.resource, name=None)
