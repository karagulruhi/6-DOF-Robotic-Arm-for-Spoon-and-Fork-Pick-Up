# %%
import shutil

# Kaynak dosyanın yolu
source_path = "/kaggle/input/cokuzadi/data.yaml"

# Hedef dosyanın yolu
destination_path = "/kaggle/working/yamall.yaml"

# Dosyayı taşı
shutil.copy(source_path, destination_path)

print(f"Dosya {destination_path} dizinine başarıyla taşındı!")
# Out:
# Dosya /kaggle/working/yamall.yaml dizinine başarıyla taşındı!

# %%
import shutil

# Kaynak ve hedef dizin yollarını belirleyin
source_path = '/kaggle/input/yolovoo'
destination_path = '/kaggle/working/yamaaal'

# Dizini taşı
shutil.copytree(source_path, destination_path)

print(f"Dizin {destination_path} dizinine başarıyla taşındı!")
# Out:
# Dizin /kaggle/working/yamaaal dizinine başarıyla taşındı!

# %%
# !git clone https://github.com/ultralytics/yolov5  # clone0
# Out:
# Cloning into 'yolov5'...
# remote: Enumerating objects: 17120, done.
# remote: Counting objects: 100% (64/64), done.
# remote: Compressing objects: 100% (52/52), done.
# remote: Total 17120 (delta 35), reused 16 (delta 12), pack-reused 17056 (from 3)
# Receiving objects: 100% (17120/17120), 15.79 MiB | 30.05 MiB/s, done.
# Resolving deltas: 100% (11737/11737), done.

# %%
#Python'da PyTorch kütüphanesini kullanarak GPU veya CPU üzerinde çalışan bir bilgisayar ortamında PyTorch'un sürümünü ve mevcut cihazın özelliklerini kontrol etmek için kullanılır.
import torch
from IPython.display import Image  # resimleri görüntülemek için
print('Using torch %s %s' % (torch.__version__, torch.cuda.get_device_properties(0) if torch.cuda.is_available() else 'CPU'))
# Out:
# Using torch 2.4.1+cu121 _CudaDeviceProperties(name='Tesla P100-PCIE-16GB', major=6, minor=0, total_memory=16269MB, multi_processor_count=56)

# %%
# %cd /kaggle/working/yolov5
# Out:
# /kaggle/working/yolov5

# %%
# !python train.py --img 640 --epochs 150 --data /kaggle/working/yamall.yaml --weights yolov5n.pt
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 906.8/906.8 kB 19.6 MB/s eta 0:00:00
# ...
# Creating new Ultralytics Settings v0.0.6 file ✅
# View Ultralytics Settings with 'yolo settings' or at '/root/.config/Ultralytics/settings.json'
# Update Settings with 'yolo settings key=value', i.e. 'yolo settings runs_dir=path/to/dir'. For help see https://docs.ultralytics.com/quickstart/#ultralytics-settings.
# wandb: WARNING ⚠️ wandb is deprecated and will be removed in a future release. See supported integrations at https://github.com/ultralytics/yolov5#integrations.
# 2025-01-12 14:30:00.829143: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:485] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2025-01-12 14:30:01.016954: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:8454] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# ...
